# %% [markdown]
# N2 Diagram Generator

# %%
import N2DiagramGenerator
# Example: Using the class with YAML content and a diagram name
with open("capella_model.yaml", "r") as f:
    yaml_content = f.read()

n2 = N2DiagramGenerator.N2DiagramGenerator(yaml_content, "[LAB] Distiller Logical System",mode="functional" )
n2.run_all()


n2 = N2DiagramGenerator.N2DiagramGenerator(yaml_content, "[LAB] Distiller Logical System",mode="component")
n2.run_all()
# Out:
# Excel file saved to [LAB]_Distiller_Logical_System_n2.xlsx
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Boil Water</th>
#       <th>Condense Steam</th>
#       <th>Discharge Residue</th>
#       <th>Distribute Clean Water</th>
#       <th>Divert Feed</th>
#       <th>Drain Residue</th>
#       <th>Generate Heat</th>
#       <th>Get Clean Water</th>
#       <th>Heat Water</th>
#       <th>Operate Distiller</th>
#       <th>Provide Water</th>
#       <th>Store Clean Water</th>
#       <th>Tend Heat Source</th>
#       <th>Tend Water Source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Boil Water</th>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>✔</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
# ...
